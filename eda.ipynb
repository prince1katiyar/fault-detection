# %%
import pandas as pd 
df=pd.read_csv(r"https://raw.githubusercontent.com/avnyadav/sensor-fault-detection/main/aps_failure_training_set1.csv")

# %%
df
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000  ag_001  \
# 0       pos  153204      0         182     na      0      0      0       0
# 1       pos  453236     na        2926     na      0      0      0       0
# 2       pos   72504     na        1594   1052      0      0      0     244
# 3       pos  762958     na          na     na     na     na    776  281128
# 4       pos  695994     na          na     na     na     na      0       0
# ...     ...     ...    ...         ...    ...    ...    ...    ...     ...
# 36183   neg  153002     na         664    186      0      0      0       0
# 36184   neg    2286     na  2130706538    224      0      0      0       0
# 36185   neg     112      0  2130706432     18      0      0      0       0
# 36186   neg   80292     na  2130706432    494      0      0      0       0
# 36187   neg   40222     na         698    628      0      0      0       0
#
# ...

# %%
# Check data types of columns in DataFrame
print(df.dtypes)
# Out:
# class     object
# aa_000     int64
# ab_000    object
# ac_000    object
# ad_000    object
#            ...
# ee_007    object
# ee_008    object
# ee_009    object
# ef_000    object
# eg_000    object
# Length: 171, dtype: object

# %%
# Separate columns into numerical and categorical
numerical_columns = []
categorical_columns = []

for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:
        numerical_columns.append(column)
    elif df[column].dtype == 'object':
        categorical_columns.append(column)

print("Numerical Columns:", numerical_columns)
print("Categorical Columns:", categorical_columns)
# Out:
# Numerical Columns: ['aa_000']
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
# Replace 'na' values with NaN using regex
df.replace(r'^na$', np.nan, regex=True, inplace=True)

# %%
# Check unique values in each column
for col in df.columns:
    unique_values = df[col].unique()
    print(f"Column '{col}': {unique_values}")
# Out:
# Column 'class': ['pos' 'neg']
# Column 'aa_000': [153204 453236  72504 ...  16978   6078 153002]
# Column 'ab_000': ['0' nan '2' '6' '8' '4' '12' '36' '10' '34' '14' '100' '48' '58' '32'
#  '28' '24' '20' '22' '18' '16' '44' '46' '68']
# Column 'ac_000': ['182' '2926' '1594' ... '1968' '2602' '2130706538']
# Column 'ad_000': [nan '1052' '856' ... '1914' '3608' '194868']
# Column 'ae_000': ['0' nan '662' '816' '1346' '1372' '18' '2' '664' '76' '4' '44' '144' '6'
#  '126' '42' '106' '484' '172' '1118' '84' '1468' '206' '168' '10' '110'
#  '266' '14' '458' '34' '1912' '98' '116' '54' '26' '12' '204' '524' '234'
#  '1270' '22' '30' '310' '2468' '612' '138' '100' '62' '24' '124' '280'
#  '228' '8' '486' '38' '140' '246' '2600' '142' '150' '1710' '478' '214'
#  '570' '96' '352' '746' '1130' '390' '90' '68' '58' '16' '480' '176' '182'
#  '256' '82' '3478' '156' '538' '1292' '122' '344' '2572' '70' '600' '28'
#  '468' '120' '180' '164' '220' '236' '314' '962' '36' '154' '540' '40'
# ...

# %%
# Replace 'na' values with NaN using regex
df.replace(r'^na$', np.nan, regex=True, inplace=True)

# %%
# Separate numerical and categorical columns
numerical_columns = [col for col in df.columns if df[col].dtype != 'object']
categorical_columns = [col for col in df.columns if df[col].dtype == 'object']

# Print out the numerical and categorical columns
print("Numerical Columns:", numerical_columns)
print("Categorical Columns:", categorical_columns)
# Out:
# Numerical Columns: ['aa_000']
# ...
